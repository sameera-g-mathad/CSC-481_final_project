# %%
import implementations as imp
import pandas as pd
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
# from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
buildings_train_images = imp.read_images(
    "/Users/sameergururajmathad/Documents/CSC - 481/Final Project/buildings-vs-forests/traning_set/buildings", "gray"
)

# %%
forest_train_images = imp.read_images("/Users/sameergururajmathad/Documents/CSC - 481/Final Project/buildings-vs-forests/traning_set/forest", format='gray')

# %%
buildings_train_images.resize(200)
forest_train_images.resize(200)

# %%
buildings_train_hog = imp.to_hog(buildings_train_images)

# %%
forest_train_hog = imp.to_hog(forest_train_images)

# %%
for hog in buildings_train_hog:
    hog.append(1)

# %%
for hog in forest_train_hog:
    hog.append(-1)

# %%
buildings_test_images = imp.read_images(
    "/Users/sameergururajmathad/Documents/CSC - 481/Final Project/buildings-vs-forests/test_set/buildings", "gray"
)

# %%
forest_test_images = imp.read_images("/Users/sameergururajmathad/Documents/CSC - 481/Final Project/buildings-vs-forests/test_set/forest", format='gray')

# %%
buildings_test_images.resize(200)
forest_test_images.resize(200)

# %%
buildings_test_hog = imp.to_hog(buildings_test_images)

# %%
forest_test_hog = imp.to_hog(forest_test_images)

# %%
for hog in buildings_test_hog:
    hog.append(1)

# %%
for hog in forest_test_hog:
    hog.append(-1)

# %%
building_train_df = pd.DataFrame(buildings_train_hog)
forest_train_df = pd.DataFrame(forest_train_hog)

building_train_df = building_train_df.rename(columns={building_train_df.columns[-1]: 'target'}) # type:ignore
forest_train_df = forest_train_df.rename(columns={forest_train_df.columns[-1]: 'target'}) # type: ignore

# %%
train_df = pd.concat([building_train_df, forest_train_df], axis='index')

# %%
building_test_df = pd.DataFrame(buildings_test_hog)
forest_test_df = pd.DataFrame(forest_test_hog)

building_test_df = building_test_df.rename(columns={building_test_df.columns[-1]: 'target'}) # type:ignore
forest_test_df = forest_test_df.rename(columns={forest_test_df.columns[-1]: 'target'}) # type: ignore

# %%
test_df = pd.concat([building_test_df, forest_test_df], axis='index')

# %%
test_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.536071  0.000000  0.011564  0.009142  0.801649  0.027426  0.164811
# 1    0.170405  0.486342  0.571098  0.175439  0.416837  0.205636  0.324152
# 2    0.710227  0.000000  0.009529  0.000000  0.690022  0.000000  0.139128
# 3    0.438759  0.021945  0.000000  0.000000  0.655411  0.000000  0.146360
# 4    0.286990  0.000000  0.000000  0.000000  0.770816  0.000000  0.185227
# ..        ...       ...       ...       ...       ...       ...       ...
# 469  0.223916  0.273281  0.135586  0.082771  0.581046  0.473988  0.354496
# 470  0.195217  0.187841  0.280409  0.197936  0.446726  0.500106  0.517460
# 471  0.485220  0.190980  0.169238  0.101813  0.369298  0.389244  0.382550
# 472  0.249360  0.077260  0.300537  0.312449  0.398092  0.220688  0.346468
# 473  0.060303  0.083396  0.053240  0.207438  0.919111  0.233723  0.138101
#
#             7         8         9  ...      5616      5617      5618  \
# ...

# %%
train_df = train_df.sample(frac=1)
test_df = test_df.sample(frac=1)

# %%
train_df
# Out:
#              0         1         2         3         4         5         6  \
# 1419  0.457096  0.000000  0.000000  0.000000  0.804878  0.000000  0.163147
# 959   0.348944  0.001989  0.004403  0.017799  0.803053  0.006076  0.159811
# 923   0.725190  0.009641  0.001016  0.000000  0.675586  0.000000  0.132623
# 1000  0.164807  0.255936  0.145936  0.431035  0.286247  0.402780  0.515278
# 581   0.000000  0.055768  0.024890  0.039889  0.560946  0.642764  0.493820
# ...        ...       ...       ...       ...       ...       ...       ...
# 1712  0.390236  0.301677  0.358936  0.489315  0.473564  0.249246  0.000000
# 1796  0.502549  0.413281  0.207619  0.229491  0.395090  0.276322  0.306466
# 1095  0.276333  0.157339  0.255086  0.162446  0.421343  0.596133  0.360304
# 1763  0.354570  0.186041  0.115096  0.032965  0.739719  0.181813  0.196105
# 1291  0.442094  0.002875  0.018007  0.090293  0.792166  0.109957  0.147926
#
# ...

# %%
test_df
# Out:
#             0         1         2         3         4         5         6  \
# 53   0.000000  0.092039  0.129377  0.375884  0.745830  0.430887  0.283308
# 185  0.700000  0.000000  0.000000  0.000000  0.700000  0.000000  0.141421
# 133  0.379406  0.301826  0.360533  0.128638  0.462772  0.318571  0.105097
# 40   0.934783  0.000000  0.000000  0.000000  0.336227  0.071634  0.000000
# 263  0.159386  0.052274  0.243026  0.412746  0.356903  0.673980  0.230511
# ..        ...       ...       ...       ...       ...       ...       ...
# 193  0.116445  0.093289  0.153583  0.260091  0.662952  0.448759  0.216058
# 111  0.224187  0.333772  0.207885  0.631905  0.305402  0.176913  0.184774
# 74   0.350103  0.002202  0.002089  0.000000  0.801160  0.003303  0.168870
# 391  0.184520  0.327538  0.185381  0.586663  0.478797  0.383601  0.169223
# 431  0.405204  0.095856  0.132889  0.730717  0.298655  0.274686  0.079276
#
#             7         8         9  ...      5616      5617      5618  \
# ...

# %%
train_X, train_y = train_df.iloc[:,:-1], train_df.iloc[:,-1]
test_X, test_y = test_df.iloc[:,:-1], test_df.iloc[:,-1]

# %%
model = SVC()
model.fit(train_X, train_y)
# Out:
# SVC()

# %%
predictions = model.predict(test_X)

# %%
accuracy_score(test_y, predictions)
# Out:
# 0.9890230515916575
