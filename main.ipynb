# %%
import implementations as imp
from implementations import ImagePacker
import pandas as pd
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
# from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
buildings_train_images = imp.read_images(
    "/Users/sameergururajmathad/Documents/CSC - 481/Final Project/buildings-vs-forests/traning_set/buildings", "gray"
)

# %%
buildings_test_images = imp.read_images(
    "/Users/sameergururajmathad/Documents/CSC - 481/Final Project/buildings-vs-forests/test_set/buildings", "gray"
)

# %%
forest_train_images = imp.read_images("/Users/sameergururajmathad/Documents/CSC - 481/Final Project/buildings-vs-forests/traning_set/forest", format='gray')

# %%
forest_test_images = imp.read_images("/Users/sameergururajmathad/Documents/CSC - 481/Final Project/buildings-vs-forests/test_set/forest", format='gray')

# %%
train_packed = ImagePacker(data = [buildings_train_images, forest_train_images])
test_packed = ImagePacker(data = [buildings_test_images, forest_test_images])

# %%
train_hog = train_packed.to_hog(append_label=[1,-1])
test_hog = test_packed.to_hog(append_label=[1,-1])

# %%
train_df = train_packed.hog_to_df(train_hog)
test_df = test_packed.hog_to_df(test_hog)

# %%
train_df
# Out:
#                                                       0         1         2  \
# 3164  /Users/sameergururajmathad/Documents/CSC - 481...  0.312150  0.044068
# 539   /Users/sameergururajmathad/Documents/CSC - 481...  0.363738  0.003921
# 4418  /Users/sameergururajmathad/Documents/CSC - 481...  0.528720  0.267122
# 3736  /Users/sameergururajmathad/Documents/CSC - 481...  0.291574  0.220653
# 3678  /Users/sameergururajmathad/Documents/CSC - 481...  0.438874  0.288498
# ...                                                 ...       ...       ...
# 1414  /Users/sameergururajmathad/Documents/CSC - 481...  0.173979  0.238635
# 4342  /Users/sameergururajmathad/Documents/CSC - 481...  0.385975  0.073209
# 3520  /Users/sameergururajmathad/Documents/CSC - 481...  0.234157  0.257655
# 1816  /Users/sameergururajmathad/Documents/CSC - 481...  0.732455  0.384683
# 3777  /Users/sameergururajmathad/Documents/CSC - 481...  0.434647  0.165985
#
#              3         4         5         6         7         8         9  \
# 3164  0.126552  0.218320  0.326838  0.639850  0.268085  0.270947  0.418841
# 539   0.014369  0.008809  0.791873  0.002778  0.162993  0.001855  0.462335
# 4418  0.228503  0.181979  0.520247  0.326587  0.169223  0.093180  0.386182
# 3736  0.146872  0.090436  0.693243  0.355230  0.239242  0.396108  0.125039
# 3678  0.041976  0.337717  0.234982  0.493999  0.291060  0.327370  0.342351
# ...        ...       ...       ...       ...       ...       ...       ...
# 1414  0.073628  0.385037  0.297824  0.482686  0.569559  0.263293  0.209059
# 4342  0.117344  0.037043  0.718485  0.115458  0.233866  0.082684  0.489326
# 3520  0.359382  0.488462  0.139426  0.284846  0.322355  0.514186  0.205321
# 1816  0.186292  0.236539  0.253659  0.099206  0.086765  0.318095  0.204879
# 3777  0.183619  0.381760  0.169646  0.364094  0.457533  0.209190  0.435469
#
#       ...      5617      5618      5619      5620      5621      5622  \
# 3164  ...  0.437601  0.026445  0.004630  0.024014  0.710657  0.191054
# 539   ...  0.916830  0.000000  0.073158  0.100029  0.198792  0.160896
# 4418  ...  0.230391  0.172748  0.251077  0.284836  0.306112  0.468247
# 3736  ...  0.429419  0.685853  0.304155  0.226042  0.345333  0.000000
# 3678  ...  0.252254  0.199021  0.326695  0.492644  0.504177  0.339871
# ...   ...       ...       ...       ...       ...       ...       ...
# 1414  ...  0.128413  0.090299  0.499901  0.515321  0.545042  0.271848
# 4342  ...  0.279803  0.320450  0.311308  0.171560  0.333595  0.315517
# 3520  ...  0.560607  0.133783  0.174536  0.247282  0.315621  0.219853
# 1816  ...  0.365137  0.402648  0.036022  0.499607  0.127483  0.505004
# 3777  ...  0.558304  0.370450  0.224751  0.208605  0.139943  0.317450
#
#           5623      5624      5625  target
# 3164  0.215589  0.048406  0.465673      -1
# 539   0.099567  0.001863  0.262186       1
# 4418  0.512152  0.274631  0.349607      -1
# 3736  0.181640  0.195718  0.105100      -1
# 3678  0.353367  0.182508  0.139451      -1
# ...        ...       ...       ...     ...
# 1414  0.140519  0.262732  0.012357       1
# 4342  0.408065  0.376659  0.416473      -1
# 3520  0.278773  0.432516  0.404320      -1
# 1816  0.145279  0.372266  0.150587       1
# 3777  0.209095  0.238210  0.486016      -1
#
# [4443 rows x 5627 columns]

# %%
test_df
# Out:
#                                                      0         1         2  \
# 546  /Users/sameergururajmathad/Documents/CSC - 481...  0.610729  0.125011
# 505  /Users/sameergururajmathad/Documents/CSC - 481...  0.336049  0.522652
# 512  /Users/sameergururajmathad/Documents/CSC - 481...  0.286190  0.276855
# 301  /Users/sameergururajmathad/Documents/CSC - 481...  0.350571  0.000000
# 389  /Users/sameergururajmathad/Documents/CSC - 481...  0.340533  0.000000
# ..                                                 ...       ...       ...
# 376  /Users/sameergururajmathad/Documents/CSC - 481...  0.455095  0.000000
# 79   /Users/sameergururajmathad/Documents/CSC - 481...  0.429651  0.029103
# 160  /Users/sameergururajmathad/Documents/CSC - 481...  0.706274  0.007354
# 460  /Users/sameergururajmathad/Documents/CSC - 481...  0.215723  0.182211
# 133  /Users/sameergururajmathad/Documents/CSC - 481...  0.927605  0.056783
#
#             3         4         5         6         7         8         9  \
# 546  0.114405  0.252081  0.492432  0.116774  0.235023  0.157296  0.445697
# 505  0.234656  0.164469  0.336013  0.298441  0.318882  0.385222  0.282379
# 512  0.614621  0.101844  0.260272  0.205445  0.191471  0.134487  0.537233
# 301  0.002019  0.000000  0.804681  0.000000  0.163073  0.001597  0.450543
# 389  0.000000  0.000000  0.807466  0.009001  0.164034  0.000000  0.452822
# ..        ...       ...       ...       ...       ...       ...       ...
# 376  0.004956  0.000000  0.807060  0.002239  0.160015  0.000000  0.340452
# 79   0.029741  0.035903  0.725256  0.158216  0.224601  0.076906  0.452760
# 160  0.001163  0.002600  0.693174  0.000000  0.143600  0.001838  0.000000
# 460  0.277872  0.301507  0.675498  0.377587  0.287766  0.184124  0.191215
# 133  0.027742  0.070521  0.081635  0.081886  0.000000  0.079258  0.333061
#
#      ...      5617      5618      5619      5620      5621      5622  \
# 546  ...  0.484348  0.321245  0.439951  0.230783  0.195385  0.061529
# 505  ...  0.442474  0.429600  0.560361  0.238164  0.214151  0.111176
# 512  ...  0.804241  0.207653  0.168836  0.009737  0.052434  0.000000
# 301  ...  0.617810  0.059744  0.491210  0.144235  0.507648  0.119488
# 389  ...  0.247878  0.011872  0.017304  0.027693  0.775807  0.024550
# ..   ...       ...       ...       ...       ...       ...       ...
# 376  ...  0.045628  0.114656  0.075367  0.234228  0.953769  0.036751
# 79   ...  0.227892  0.190730  0.022321  0.239677  0.856514  0.157579
# 160  ...  0.566175  0.023292  0.011278  0.017832  0.735137  0.026748
# 460  ...  0.563718  0.043712  0.104499  0.088875  0.306653  0.464653
# 133  ...  0.733502  0.001771  0.132814  0.074620  0.153782  0.145105
#
#          5623      5624      5625  target
# 546  0.423166  0.142449  0.417215      -1
# 505  0.193944  0.115146  0.373952      -1
# 512  0.154753  0.072700  0.499494      -1
# 301  0.264498  0.059744  0.084491       1
# 389  0.168918  0.010410  0.553378       1
# ..        ...       ...       ...     ...
# 376  0.026754  0.104422  0.039798       1
# 79   0.042061  0.221997  0.210346       1
# 160  0.169480  0.067872  0.322468       1
# 460  0.144566  0.363605  0.445472      -1
# 133  0.104403  0.124816  0.606284       1
#
# [911 rows x 5627 columns]

# %%
train_X, train_y = train_df.iloc[:,2:-1], train_df.iloc[:,-1]
test_X, test_y = test_df.iloc[:,2:-1], test_df.iloc[:,-1]

# %%
model = SVC()
model.fit(train_X, train_y)
# Out:
# SVC()

# %%
predictions = model.predict(test_X)

# %%
accuracy_score(test_y, predictions)
# Out:
# 0.9890230515916575
