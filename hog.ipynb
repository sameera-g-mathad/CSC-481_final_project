# %%
import implementations as imp
from implementations import ImagePacker
import pandas as pd
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
# from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
buildings_train_images = imp.read_images(
    "/Users/sameergururajmathad/Documents/CSC - 481/Final Project/buildings-vs-forests/traning_set/buildings", "gray"
)

# %%
buildings_test_images = imp.read_images(
    "/Users/sameergururajmathad/Documents/CSC - 481/Final Project/buildings-vs-forests/test_set/buildings", "gray"
)

# %%
forest_train_images = imp.read_images("/Users/sameergururajmathad/Documents/CSC - 481/Final Project/buildings-vs-forests/traning_set/forest", format='gray')

# %%
forest_test_images = imp.read_images("/Users/sameergururajmathad/Documents/CSC - 481/Final Project/buildings-vs-forests/test_set/forest", format='gray')

# %%
train_packed = ImagePacker(data = [buildings_train_images, forest_train_images])
test_packed = ImagePacker(data = [buildings_test_images, forest_test_images])

# %%
train_hog = train_packed.to_hog(append_label=[1,-1])
test_hog = test_packed.to_hog(append_label=[1,-1])

# %%
train_df = train_packed.descriptor_to_df(train_hog)
test_df = test_packed.descriptor_to_df(test_hog)

# %%
train_df
# Out:
#                                                       0         1         2  \
# 956   /Users/sameergururajmathad/Documents/CSC - 481...  0.317922  0.449929
# 693   /Users/sameergururajmathad/Documents/CSC - 481...  0.466129  0.005040
# 1717  /Users/sameergururajmathad/Documents/CSC - 481...  0.264821  0.006577
# 4266  /Users/sameergururajmathad/Documents/CSC - 481...  0.315704  0.092113
# 1592  /Users/sameergururajmathad/Documents/CSC - 481...  0.229153  0.000000
# ...                                                 ...       ...       ...
# 1722  /Users/sameergururajmathad/Documents/CSC - 481...  0.552623  0.001382
# 1480  /Users/sameergururajmathad/Documents/CSC - 481...  0.704682  0.000000
# 2457  /Users/sameergururajmathad/Documents/CSC - 481...  0.205584  0.080145
# 3670  /Users/sameergururajmathad/Documents/CSC - 481...  0.137377  0.194251
# 2212  /Users/sameergururajmathad/Documents/CSC - 481...  0.101307  0.011448
#
#              3         4         5         6         7         8         9  \
# 956   0.219394  0.458551  0.281886  0.485666  0.321527  0.094187  0.102493
# 693   0.005738  0.001008  0.800182  0.000000  0.160976  0.000000  0.341262
# 1717  0.007699  0.102940  0.473425  0.134079  0.171374  0.612372  0.522200
# 4266  0.468054  0.222675  0.525599  0.422908  0.172477  0.370452  0.033169
# 1592  0.000000  0.000000  0.789562  0.000000  0.213499  0.000000  0.527729
# ...        ...       ...       ...       ...       ...       ...       ...
# 1722  0.008742  0.006911  0.786889  0.004147  0.162158  0.000000  0.221303
# 1480  0.000797  0.000000  0.695105  0.000000  0.142311  0.000000  0.000000
# 2457  0.104170  0.402942  0.715327  0.456231  0.143064  0.013800  0.193912
# 3670  0.043463  0.115940  0.418013  0.530101  0.536757  0.251138  0.348055
# 2212  0.004756  0.010410  0.841478  0.062755  0.101909  0.004227  0.516766
#
#       ...      5617      5618      5619      5620      5621      5622  \
# 956   ...  0.506640  0.026354  0.075677  0.032688  0.730433  0.128247
# 693   ...  0.547403  0.012456  0.001789  0.259706  0.658462  0.168646
# 1717  ...  0.661810  0.181749  0.076042  0.159087  0.322079  0.170526
# 4266  ...  0.197113  0.520758  0.192263  0.106145  0.108465  0.181879
# 1592  ...  0.653550  0.058455  0.018485  0.000000  0.695229  0.107786
# ...   ...       ...       ...       ...       ...       ...       ...
# 1722  ...  0.111930  0.000000  0.000000  0.000000  0.709952  0.207148
# 1480  ...  0.311119  0.058977  0.018307  0.135185  0.677199  0.041275
# 2457  ...  0.366103  0.247016  0.168347  0.129249  0.070780  0.258652
# 3670  ...  0.512408  0.175300  0.168368  0.147477  0.294489  0.291673
# 2212  ...  0.228788  0.170935  0.183438  0.050682  0.331917  0.674735
#
#           5623      5624      5625  target
# 956   0.234163  0.007168  0.361888       1
# 693   0.341043  0.057434  0.226100       1
# 1717  0.137845  0.428049  0.403538       1
# 4266  0.432667  0.524341  0.367078      -1
# 1592  0.184852  0.029228  0.197808       1
# ...        ...       ...       ...     ...
# 1722  0.206563  0.092075  0.624006       1
# 1480  0.175579  0.011032  0.624391       1
# 2457  0.554010  0.535725  0.306704      -1
# 3670  0.091807  0.273953  0.633510      -1
# 2212  0.206552  0.288421  0.436958      -1
#
# [4443 rows x 5627 columns]

# %%
test_df
# Out:
#                                                      0         1         2  \
# 345  /Users/sameergururajmathad/Documents/CSC - 481...  0.106194  0.085752
# 725  /Users/sameergururajmathad/Documents/CSC - 481...  0.308072  0.205652
# 182  /Users/sameergururajmathad/Documents/CSC - 481...  0.566262  0.003131
# 347  /Users/sameergururajmathad/Documents/CSC - 481...  0.332505  0.000000
# 255  /Users/sameergururajmathad/Documents/CSC - 481...  0.379533  0.022104
# ..                                                 ...       ...       ...
# 715  /Users/sameergururajmathad/Documents/CSC - 481...  0.335605  0.021665
# 4    /Users/sameergururajmathad/Documents/CSC - 481...  0.286990  0.000000
# 723  /Users/sameergururajmathad/Documents/CSC - 481...  0.189563  0.130924
# 117  /Users/sameergururajmathad/Documents/CSC - 481...  0.347785  0.257131
# 315  /Users/sameergururajmathad/Documents/CSC - 481...  0.355044  0.004460
#
#             3         4         5         6         7         8         9  \
# 345  0.168131  0.019566  0.100943  0.177264  0.802189  0.501134  0.128313
# 725  0.026026  0.213886  0.514223  0.313122  0.398143  0.351062  0.414898
# 182  0.003032  0.000000  0.768267  0.000000  0.157686  0.015608  0.252955
# 347  0.000000  0.007664  0.817449  0.005748  0.162379  0.000000  0.441315
# 255  0.008552  0.007900  0.789290  0.004507  0.167825  0.004845  0.451821
# ..        ...       ...       ...       ...       ...       ...       ...
# 715  0.013246  0.002565  0.816241  0.019577  0.165060  0.002776  0.439127
# 4    0.000000  0.000000  0.770816  0.000000  0.185227  0.017228  0.537469
# 723  0.230907  0.210484  0.711429  0.540960  0.117282  0.183881  0.054465
# 117  0.184328  0.142414  0.390877  0.171681  0.532441  0.183681  0.509096
# 315  0.014104  0.004460  0.797876  0.000000  0.165019  0.000000  0.458114
#
#      ...      5617      5618      5619      5620      5621      5622  \
# 345  ...  0.135684  0.007580  0.007701  0.007932  0.731619  0.010037
# 725  ...  0.275617  0.163294  0.470315  0.257250  0.420881  0.438830
# 182  ...  0.512723  0.100737  0.031294  0.131808  0.557487  0.235072
# 347  ...  0.482352  0.154652  0.183167  0.160198  0.155102  0.140844
# 255  ...  0.496144  0.012589  0.002721  0.003375  0.757616  0.005495
# ..   ...       ...       ...       ...       ...       ...       ...
# 715  ...  0.209591  0.176145  0.068162  0.203925  0.455055  0.377366
# 4    ...  0.497248  0.064147  0.067516  0.089096  0.756139  0.030034
# 723  ...  0.309580  0.200001  0.135389  0.118746  0.217773  0.512966
# 117  ...  0.970211  0.159093  0.113950  0.001956  0.025644  0.012226
# 315  ...  0.287298  0.459383  0.068047  0.371251  0.120368  0.588401
#
#          5623      5624      5625  target
# 345  0.150409  0.013439  0.650568       1
# 725  0.217490  0.219230  0.380685      -1
# 182  0.255931  0.028292  0.525607       1
# 347  0.312635  0.369343  0.637305       1
# 255  0.163359  0.031525  0.389835       1
# ..        ...       ...       ...     ...
# 715  0.562842  0.353581  0.295842      -1
# 4    0.200966  0.054003  0.346672       1
# 723  0.616582  0.284922  0.244574      -1
# 117  0.111053  0.076826  0.036735       1
# 315  0.406088  0.160546  0.112173       1
#
# [911 rows x 5627 columns]

# %%
train_X, train_y = train_df.iloc[:,2:-1], train_df.iloc[:,-1]
test_X, test_y = test_df.iloc[:,2:-1], test_df.iloc[:,-1]

# %%
model = SVC()
model.fit(train_X, train_y)
# Out:
# SVC()

# %%
predictions = model.predict(test_X)

# %%
accuracy_score(test_y, predictions)
# Out:
# 0.9890230515916575
